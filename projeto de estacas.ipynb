# %% [markdown]
# # Projeto de estacas escavadas

# %%
import pandas as pd

from estacas import *

# %% [markdown]
# ## Entrada do usuário

# %%
tipo_estaca = 'escavada'
diametro = 0.3

# %% [markdown]
# ## Capacidade de carga

# %%
df = pd.read_excel('./sondagem.xlsx')
df['tipo estaca'] = tipo_estaca
df['diâmetro (m)'] = diametro
df['area estaca (m2)'] = df.apply(area_estaca, axis=1)
df['perimetro estaca (m)'] = df.apply(perimetro_estaca, axis=1)
df['k'] = df.apply(k_solo, axis=1, args=(k_alpha,))
df['alpha'] = df.apply(alpha_solo, axis=1, args=(k_alpha,))
df['f_1'] = df.apply(f1, axis=1, args=(f_1,))
df['f_2'] = 2 * df['f_1']
df['r_p (kPa)'] = df.apply(tensao_ponta, axis=1)
df['P_p (kN)'] = df.apply(carga_ponta, axis=1)
df['r_l (kPa)'] = df.apply(tensao_lateral, axis=1)
df['P_l (kN)'] = df.apply(carga_lateral, axis=1)
soma_resultados = []
r_l = df['r_l (kPa)'].to_list()
for i in range(len(df)):
    if i == 0:
        soma = df.iloc[i]['r_p (kPa)'] + df.iloc[i]['r_l (kPa)']
    else:
        soma = df.iloc[i]['r_p (kPa)'] + sum(r_l[:i+1])
    soma_resultados.append(soma)
df['r_rd [Aoki-Veloso] (kPa)'] = soma_resultados
df['P_rd [Aoki-Veloso] (kN)'] = df.apply(carga_total, axis=1)
df
# Out:
#    profundidade (m)  NSPT                                               Solo  \
# 0                 1     2  argila-arenosa, fina a méda, de consistencia m...
# 1                 2     6  argila-arenosa, fina a méda, de consistencia m...
# 2                 3     6  argila-siltosa, fina a média, de consistencia ...
# 3                 4    50  argila-siltosa, fina a média, de consistencia ...
# 4                 5    60  argila- siltosa-arenosa, fina a média, de cons...
# 5                 6    78  argila- siltosa-arenosa, fina a média, de cons...
#
#       Solo Aoki-Veloso Solo Decourt-Quaresma  tipo estaca  diâmetro (m)  \
# 0       argila arenosa                argila     escavada           0.3
# 1       argila arenosa                argila     escavada           0.3
# 2       argila siltosa                argila     escavada           0.3
# 3       argila siltosa                argila     escavada           0.3
# 4  argila siltoarenosa                argila     escavada           0.3
# 5  argila siltoarenosa                argila     escavada           0.3
#
#    area estaca (m2)  perimetro estaca (m)     k  alpha  f_1  f_2    r_p (kPa)  \
# 0          0.070686              0.942478  0.35    2.4  3.0  6.0   233.333333
# 1          0.070686              0.942478  0.35    2.4  3.0  6.0   700.000000
# 2          0.070686              0.942478  0.22    4.0  3.0  6.0   440.000000
# 3          0.070686              0.942478  0.22    4.0  3.0  6.0  3666.666667
# 4          0.070686              0.942478  0.33    3.0  3.0  6.0  6600.000000
# 5          0.070686              0.942478  0.33    3.0  3.0  6.0  8580.000000
#
#      P_p (kN)     r_l (kPa)    P_l (kN)  r_rd [Aoki-Veloso] (kPa)  \
# 0   16.493361    263.893783   18.653552                497.227116
# 1   49.480084    791.681349   55.960657               1755.575132
# 2   31.101767    829.380461   58.625450               2324.955592
# 3  259.181394   6911.503838  488.545418              12463.126097
# 4  466.526509   9330.530181  659.536314              24726.989611
# 5  606.484462  12129.689236  857.397208              38836.678847
#
#    P_rd [Aoki-Veloso] (kN)
# 0                35.146914
# 1               124.094294
# 2               164.341427
# 3               880.966471
# 4              1747.847900
# 5              2745.203061

# %%
# Exemplo de lista
lista = [1, 2, 3, 4, 5]

# Soma até o elemento 2
soma_ate_2 = sum(lista[:3])  # O terceiro elemento não é incluído

# Soma até o elemento 3
soma_ate_3 = sum(lista[:4])  # O quarto elemento não é incluído

print("Soma até o elemento 2:", soma_ate_2, lista[:1])
print("Soma até o elemento 3:", soma_ate_3)
# Out:
# Soma até o elemento 2: 6 [1]
# Soma até o elemento 3: 10
