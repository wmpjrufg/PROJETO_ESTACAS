# %% [markdown]
# # Projeto de estacas escavadas

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

from estacas import *

# %% [markdown]
# ## Entrada do usuário

# %%
tipo_estaca = 'Franki'
f_ck = 25000 # Tensão de compressão característica do concreto (kPa)

# %% [markdown]
# ## Capacidade de carga

# %%
df = pd.read_excel('./sondagem2.xlsx')
df['tipo estaca'] = tipo_estaca.lower()
df['area estaca (m2)'] = df.apply(area_estaca, axis=1)
df['perimetro estaca (m)'] = df.apply(perimetro_estaca, axis=1)
df['k'] = df.apply(k_solo, axis=1)
df['alpha'] = df.apply(alpha_solo, axis=1)
df['f_1'] = df.apply(f1, axis=1)
df['f_2'] = 2 * df['f_1']
df['r_p [Aoki-Veloso] (kPa)'] = df.apply(tensao_ponta_aoki_veloso, axis=1)
df['P_p [Aoki-Veloso] (kN)'] = df.apply(carga_ponta_aoki_veloso, axis=1)
df['r_l [Aoki-Veloso] (kPa)'] = df.apply(tensao_lateral_aoki_veloso, axis=1)
soma_resultados = []
r_l = df['r_l [Aoki-Veloso] (kPa)'].to_list()
for i in range(len(df)):
    if i == 0:
        soma = df.iloc[i]['r_l [Aoki-Veloso] (kPa)']
    else:
        soma = sum(r_l[:i+1])
    soma_resultados.append(soma)
df['r_l acumulado [Aoki-Veloso] (kPa)'] = soma_resultados
df['P_l [Aoki-Veloso] (kN)'] = df.apply(carga_lateral_aoki_veloso, axis=1)
df['r_rd [Aoki-Veloso] (kPa)'] = df['r_l acumulado [Aoki-Veloso] (kPa)'] + df['r_p [Aoki-Veloso] (kPa)']
df['P_rd [Aoki-Veloso] (kN)'] = df['P_p [Aoki-Veloso] (kN)'] + df['P_l [Aoki-Veloso] (kN)']
df['c'] = df.apply(c_solo, axis=1)
df['r_p [Decourt-Quaresma] (kPa)'] = df.apply(tensao_ponta_decorto_quaresma, axis=1)
df['P_p [Decourt-Quaresma] (kN)'] = df.apply(carga_ponta_decourt_quaresma, axis=1)
n_spt = df['NSPT'].to_list()
soma_resultados = []
for i in range(len(df)):
    if i == 0:
        soma = df.iloc[i]['NSPT']
    else:
        soma = sum(n_spt[:i+1]) / (i+1)
    soma_resultados.append(soma)
df['nspt_medio'] = soma_resultados
df['r_l acumulado [Decourt-Quaresma] (kPa)'] = df.apply(tensao_lateral_decourt_quaresma, axis=1)
df['P_l [Decourt-Quaresma] (kN)'] = df.apply(carga_lateral_decourt_quaresma, axis=1)
df['r_rd [Decourt-Quaresma] (kPa)'] = df['r_l acumulado [Decourt-Quaresma] (kPa)'] + df['r_p [Decourt-Quaresma] (kPa)']
df['P_rd [Decourt-Quaresma] (kN)'] = df['P_p [Decourt-Quaresma] (kN)'] + df['P_l [Decourt-Quaresma] (kN)']
# Out:
#    profundidade (m)  NSPT  diâmetro (m)  Solo     Solo Aoki-Veloso  \
# 0                 1     2           0.4   NaN       argila arenosa
# 1                 2     2           0.4   NaN       argila arenosa
# 2                 3     5           0.4   NaN  argila siltoarenosa
# 3                 4     4           0.4   NaN        areia siltosa
# 4                 5     5           0.4   NaN        areia siltosa
# 5                 6     5           0.4   NaN        areia siltosa
# 6                 7     9           0.4   NaN        areia siltosa
# 7                 8    10           0.4   NaN        areia siltosa
# 8                 9    18           0.7   NaN        areia siltosa
#
#   Solo Decourt-Quaresma tipo estaca  area estaca (m2)  perimetro estaca (m)  \
# 0                argila      franki          0.125664              1.256637
# 1                argila      franki          0.125664              1.256637
# 2                argila      franki          0.125664              1.256637
# 3         silte arenoso      franki          0.125664              1.256637
# 4         silte arenoso      franki          0.125664              1.256637
# 5         silte arenoso      franki          0.125664              1.256637
# 6         silte arenoso      franki          0.125664              1.256637
# 7         silte arenoso      franki          0.125664              1.256637
# 8         silte arenoso      franki          0.384845              2.199115
#
#       k  alpha  f_1  f_2  r_p [Aoki-Veloso] (kPa)  P_p [Aoki-Veloso] (kN)  \
# 0  0.35    2.4  2.5  5.0                    280.0               35.185838
# 1  0.35    2.4  2.5  5.0                    280.0               35.185838
# 2  0.33    3.0  2.5  5.0                    660.0               82.938046
# 3  0.80    2.0  2.5  5.0                   1280.0              160.849544
# 4  0.80    2.0  2.5  5.0                   1600.0              201.061930
# 5  0.80    2.0  2.5  5.0                   1600.0              201.061930
# 6  0.80    2.0  2.5  5.0                   2880.0              361.911474
# 7  0.80    2.0  2.5  5.0                   3200.0              402.123860
# 8  0.80    2.0  2.5  5.0                   5760.0             2216.707776
#
#    r_l [Aoki-Veloso] (kPa)  r_l acumulado [Aoki-Veloso] (kPa)  \
# 0                     3.36                               3.36
# 1                     3.36                               6.72
# 2                     9.90                              16.62
# 3                    12.80                              29.42
# 4                    16.00                              45.42
# 5                    16.00                              61.42
# 6                    28.80                              90.22
# 7                    32.00                             122.22
# 8                    57.60                             179.82
#
#    P_l [Aoki-Veloso] (kN)  r_rd [Aoki-Veloso] (kPa)  P_rd [Aoki-Veloso] (kN)  \
# 0                4.222301                    283.36                39.408138
# 1                8.444601                    286.72                43.630439
# 2               20.885308                    676.62               103.823354
# 3               36.970262                   1309.42               197.819806
# 4               57.076455                   1645.42               258.138385
# 5               77.182648                   1661.42               278.244578
# 6              113.373796                   2970.22               475.285269
# 7              153.586182                   3322.22               555.710041
# 8              395.444834                   5939.82              2612.152610
#
#      c  r_p [Decourt-Quaresma] (kPa)  P_p [Decourt-Quaresma] (kN)  nspt_medio  \
# 0  120                           240                    30.159289    2.000000
# 1  120                           240                    30.159289    2.000000
# 2  120                           600                    75.398224    3.000000
# 3  250                          1000                   125.663706    3.250000
# 4  250                          1250                   157.079633    3.600000
# 5  250                          1250                   157.079633    3.833333
# 6  250                          2250                   282.743339    4.571429
# 7  250                          2500                   314.159265    5.250000
# 8  250                          4500                  1731.802950    6.666667
#
#    r_l acumulado [Decourt-Quaresma] (kPa)  P_l [Decourt-Quaresma] (kN)  \
# 0                               16.666667                    20.943951
# 1                               16.666667                    41.887902
# 2                               20.000000                    75.398224
# 3                               20.833333                   104.719755
# 4                               22.000000                   138.230077
# 5                               22.777778                   171.740398
# 6                               25.238095                   222.005881
# 7                               27.500000                   276.460154
# 8                               32.222222                   637.743309
#
#    r_rd [Decourt-Quaresma] (kPa)  P_rd [Decourt-Quaresma] (kN)
# 0                     256.666667                     51.103240
# 1                     256.666667                     72.047192
# 2                     620.000000                    150.796447
# 3                    1020.833333                    230.383461
# 4                    1272.000000                    295.309709
# 5                    1272.777778                    328.820031
# 6                    2275.238095                    504.749220
# 7                    2527.500000                    590.619419
# 8                    4532.222222                   2369.546259

# %%
# Exemplo de lista
lista = [1, 2, 3, 4, 5]

# Soma até o elemento 2
soma_ate_2 = sum(lista[:3])  # O terceiro elemento não é incluído

# Soma até o elemento 3
soma_ate_3 = sum(lista[:4])  # O quarto elemento não é incluído

print("Soma até o elemento 2:", soma_ate_2, lista[:1])
print("Soma até o elemento 3:", soma_ate_3)
# Out:
# Soma até o elemento 2: 6 [1]
# Soma até o elemento 3: 10
